# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
X = pd.read_csv('data/train_X_beta.csv', index_col=0)
y = pd.read_csv('data/train_y_beta.csv', index_col=0)
whole_df = pd.concat([X, y], axis=1)

# %%
whole_df.head()
# Out:
#                 1         2         9        10        12        13        14  \
# hct15    3.500325  3.756189  7.506203  4.122036  4.173129  3.503203  9.268220
# jhh4     3.966084  3.634253  5.373000  4.021875  4.188665  3.537557  8.987120
# snu1105  5.987927  3.735161  6.718164  4.358988  4.054809  3.826454  8.876455
# j82      4.717745  3.816445  8.329890  4.542543  4.443213  3.834258  8.612918
# dang     4.099564  3.677475  7.171958  3.949591  3.837196  8.140680  8.946058
#
#                15         16        18  ...  100630918  100631378  100642175  \
# hct15    3.811040   9.685387  5.303841  ...   5.094173   3.838323   5.096992
# jhh4     3.523175   9.438923  3.700196  ...   5.462230   3.554032   5.974853
# snu1105  3.604815   9.886685  4.002146  ...   4.850331   3.608216   5.427099
# j82      3.683737  10.086658  5.139002  ...   5.375150   3.474723   4.517609
# dang     3.357206   9.466033  3.623898  ...   5.234944   3.462128   6.323425
#
# ...

# %%
whole_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 444 entries, hct15 to saos2
# Columns: 18524 entries, 1 to Beta
# dtypes: float64(18524)
# memory usage: 62.8+ MB

# %%
whole_df.describe()
# Out:
#                 1           2           9          10          12          13  \
# count  444.000000  444.000000  444.000000  444.000000  444.000000  444.000000
# mean     4.753849    3.983415    8.001787    4.480952    4.930591    4.405809
# std      0.896184    0.637266    1.157853    0.681517    2.027368    1.489874
# min      3.053338    3.367974    3.867514    3.659009    3.418317    3.270635
# 25%      4.058643    3.672148    7.477416    4.141265    3.902121    3.603258
# 50%      4.384353    3.793058    8.117009    4.300767    4.135246    3.766393
# 75%      5.436424    3.964139    8.696005    4.553471    4.699286    4.321962
# max      7.961095    6.995033   11.734768    9.941449   13.707150   12.065143
#
#                14          15          16          18  ...   100630918  \
# count  444.000000  444.000000  444.000000  444.000000  ...  444.000000
# mean     8.830729    3.533629   10.104300    5.324830  ...    5.462586
# ...

# %%
#scatterplot
sns.set()
cols = whole_df.columns.tolist()
sns.pairplot(whole_df[cols], height = 2.5)
plt.show();
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [18], in <cell line: 4>()
#       2 sns.set()
#       3 cols = whole_df.columns.tolist()
# ----> 4 sns.pairplot(whole_df[cols], height = 2.5)
#       5 plt.show()
#
# File ~\Documents\GitHub\RadiationProject\venv\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
# %matplotlib inline
plt.figure(figsize=(12,10))
cor = whole_df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 3>()
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 plt.figure(figsize=(12,10))
# ----> 3 cor = whole_df.corr()
#       4 sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
#       5 plt.show()
#
# File ~\Documents\GitHub\RadiationProject\venv\lib\site-packages\pandas\core\frame.py:9540, in DataFrame.corr(self, method, min_periods)
#    9537 mat = numeric_df.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    9539 if method == "pearson":
# -> 9540     correl = libalgos.nancorr(mat, minp=min_periods)
#    9541 elif method == "spearman":
#    9542     correl = libalgos.nancorr_spearman(mat, minp=min_periods)
#
# KeyboardInterrupt:

# %%
cor = whole_df.corr()
corr_Profit=cor["Beta"].sort_values(ascending=False)
print(corr_Profit)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 cor = whole_df.corr()
#       2 corr_Profit=cor["Beta"].sort_values(ascending=False)
#       3 print(corr_Profit)
#
# File ~\Documents\GitHub\RadiationProject\venv\lib\site-packages\pandas\core\frame.py:9540, in DataFrame.corr(self, method, min_periods)
#    9537 mat = numeric_df.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    9539 if method == "pearson":
# -> 9540     correl = libalgos.nancorr(mat, minp=min_periods)
#    9541 elif method == "spearman":
#    9542     correl = libalgos.nancorr_spearman(mat, minp=min_periods)
#
# KeyboardInterrupt:

# %%
#Normality
#histogram and normal probability plot
from scipy.stats import norm
from scipy import stats
sns.distplot(whole_df['Beta'], fit=norm);
fig = plt.figure()
res = stats.probplot(whole_df['Beta'], plot=plt)
# Out:
# C:\Users\Udi\Documents\GitHub\RadiationProject\venv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
# drop the 1 column in X
RFE_regressor = LinearRegression()
#Initializing RFE model
rfe = RFE(RFE_regressor)# random number(2)
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,y)
#Fitting the data to model
RFE_regressor.fit(X,y)
print(rfe.support_)
print(rfe.ranking_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 8>()
#       6 rfe = RFE(RFE_regressor)# random number(2)
#       7 #Transforming data using RFE
# ----> 8 X_rfe = rfe.fit_transform(X,y)
#       9 #Fitting the data to model
#      10 RFE_regressor.fit(X,y)
#
# File ~\Documents\GitHub\RadiationProject\venv\lib\site-packages\sklearn\base.py:870, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     867     return self.fit(X, **fit_params).transform(X)
#     868 else:
#     869     # fit method of arity 2 (supervised transformation)
# --> 870     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\Documents\GitHub\RadiationProject\venv\lib\site-packages\sklearn\feature_selection\_rfe.py:235, in RFE.fit(self, X, y, **fit_params)
#     215 def fit(self, X, y, **fit_params):
# ...

# %%
#-------before calc high score it says all true ----

from sklearn.model_selection  import train_test_split
from sklearn.linear_model import LinearRegression
#no of features
nof_list=np.arange(1,4)
high_score=0
#Variable to store the optimum features
nof=0
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 11>()
#      12 X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)
#      13 model = LinearRegression()
# ---> 14 rfe = RFE(model,nof_list[n])
#      15 X_train_rfe = rfe.fit_transform(X_train,y_train)
#      16 X_test_rfe = rfe.transform(X_test)
#
# TypeError: __init__() takes 2 positional arguments but 3 were given
