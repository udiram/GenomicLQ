# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
df_x_train = pd.read_csv('data/x_train_class.csv', index_col=0)
df_y_train = pd.read_csv('data/y_train_class.csv', index_col=0)

# %%
df_x_train.head()
# Out:
#               1         2         9        10        12        13        14  \
# sw948  4.063884  3.594257  9.529689  6.740306  3.830637  3.751455  9.514933
# mkn45  3.795708  3.587633  7.474039  4.230111  4.136858  8.231481  9.248871
# j82    4.717745  3.816445  8.329890  4.542543  4.443213  3.834258  8.612918
# sknfi  4.338183  3.749382  8.297267  5.911274  3.915953  3.699066  8.846982
# te14   4.182824  3.627189  8.209574  3.672721  3.418317  5.969488  9.005162
#
#              15         16        18  ...  100628307  100630918  100631378  \
# sw948  3.385997   9.125257  6.499964  ...   3.451310   5.681741   3.452094
# mkn45  3.343609  10.242179  4.155514  ...   3.517266   5.471486   3.456001
# j82    3.683737  10.086658  5.139002  ...   3.627550   5.375150   3.474723
# sknfi  3.763437   9.328351  7.383348  ...   3.945743   5.570602   3.541147
# te14   3.404797  10.624380  4.212197  ...   3.584055   4.442833   3.514525
#
#        100642175  100652770  100652791  100653022  100689073  100689074  \
# sw948   5.541555   5.345914   3.306113   4.295348   3.260120   3.234298
# mkn45   6.452955   4.510197   3.273790   4.282714   3.577665   3.363534
# j82     4.517609   4.268056   3.476972   3.994838   3.683059   3.375735
# sknfi   6.887191   4.065278   3.414457   3.906975   3.582676   3.187661
# te14    4.820618   4.510451   3.118535   4.811349   3.593005   6.203332
#
#        100820829
# sw948   6.773936
# mkn45   5.897890
# j82     5.427906
# sknfi   4.919210
# te14    5.143104
#
# [5 rows x 18523 columns]

# %%
df_y_train.head()
# Out:
#                Beta
# cell_line
# sw948      0.037500
# mkn45      0.026786
# j82        0.012500
# sknfi      0.012500
# te14       0.023214

# %%
full_df = pd.concat([df_x_train, df_y_train], axis=1)
full_df.head()
# Out:
#                   1         2         9        10        12        13  \
# cell_line
# sw948      4.063884  3.594257  9.529689  6.740306  3.830637  3.751455
# mkn45      3.795708  3.587633  7.474039  4.230111  4.136858  8.231481
# j82        4.717745  3.816445  8.329890  4.542543  4.443213  3.834258
# sknfi      4.338183  3.749382  8.297267  5.911274  3.915953  3.699066
# te14       4.182824  3.627189  8.209574  3.672721  3.418317  5.969488
#
#                  14        15         16        18  ...  100630918  100631378  \
# cell_line                                           ...
# sw948      9.514933  3.385997   9.125257  6.499964  ...   5.681741   3.452094
# mkn45      9.248871  3.343609  10.242179  4.155514  ...   5.471486   3.456001
# j82        8.612918  3.683737  10.086658  5.139002  ...   5.375150   3.474723
# sknfi      8.846982  3.763437   9.328351  7.383348  ...   5.570602   3.541147
# te14       9.005162  3.404797  10.624380  4.212197  ...   4.442833   3.514525
#
#            100642175  100652770  100652791  100653022  100689073  100689074  \
# cell_line
# sw948       5.541555   5.345914   3.306113   4.295348   3.260120   3.234298
# mkn45       6.452955   4.510197   3.273790   4.282714   3.577665   3.363534
# j82         4.517609   4.268056   3.476972   3.994838   3.683059   3.375735
# sknfi       6.887191   4.065278   3.414457   3.906975   3.582676   3.187661
# te14        4.820618   4.510451   3.118535   4.811349   3.593005   6.203332
#
#            100820829      Beta
# cell_line
# sw948       6.773936  0.037500
# mkn45       5.897890  0.026786
# j82         5.427906  0.012500
# sknfi       4.919210  0.012500
# te14        5.143104  0.023214
#
# [5 rows x 18524 columns]

# %%
sns.countplot(x = 'Beta', data=full_df)
# Out:
# <AxesSubplot:xlabel='Beta', ylabel='count'>

# %%
class2idx = {
    0.001785715:0,
    0.005357145:1,
    0.008928575:2,
    0.0125:3,
    0.016071425:4,
    0.019642855:5,
    0.023214285:6,
    0.026785715:7,
    0.030357145:8,
    0.033928575:9,
    0.0375:10,
    0.037500000000000006:10,
    0.041071425:11,
    0.044642855:12,
}

idx2class = {v: k for k, v in class2idx.items()}

full_df['Beta'].replace(class2idx, inplace=True)

# %%
full_df.to_csv('data/full_df.csv')

# %%
X = full_df.iloc[:, 0:-1]
y = full_df.iloc[:, -1]

# %%
# Split into train+val and test
X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=69)

# Split train into train-val
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.1, stratify=y_trainval, random_state=21)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)
X_train, y_train = np.array(X_train), np.array(y_train)
X_val, y_val = np.array(X_val), np.array(y_val)
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
def get_class_distribution(obj):
    count_dict = {
        "class_0": 0,
        "class_1": 0,
        "class_2": 0,
        "class_3": 0,
        "class_4": 0,
        "class_5": 0,
        "class_6": 0,
        "class_7": 0,
        "class_8": 0,
        "class_9": 0,
        "class_10": 0,
        "class_11": 0,
        "class_12": 0,

    }

    for i in obj:
        if i == 0:
            count_dict['class_0'] += 1
        elif i == 1:
            count_dict['class_1'] += 1
        elif i == 2:
            count_dict['class_2'] += 1
        elif i == 3:
            count_dict['class_3'] += 1
        elif i == 4:
            count_dict['class_4'] += 1
        elif i == 5:
            count_dict['class_5'] += 1
        elif i == 6:
            count_dict['class_6'] += 1
        elif i == 7:
            count_dict['class_7'] += 1
        elif i==8:
            count_dict['class_8'] += 1
        elif i==9:
            count_dict['class_9'] += 1
        elif i==10:
            count_dict['class_10'] += 1
        elif i==11:
            count_dict['class_11'] += 1
        elif i==12:
            count_dict['class_12'] += 1
        else:
            print("Check classes.")
            print(i)

    return count_dict

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25,7))
# Train
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_train)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[0]).set_title('Class Distribution in Train Set')
# Validation
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_val)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[1]).set_title('Class Distribution in Val Set')
# Test
sns.barplot(data = pd.DataFrame.from_dict([get_class_distribution(y_test)]).melt(), x = "variable", y="value", hue="variable",  ax=axes[2]).set_title('Class Distribution in Test Set')
# Out:
# Text(0.5, 1.0, 'Class Distribution in Test Set')

# %%
class ClassifierDataset(Dataset):

    def __init__(self, X_data, y_data):
        self.X_data = X_data
        self.y_data = y_data

    def __getitem__(self, index):
        return self.X_data[index], self.y_data[index]

    def __len__ (self):
        return len(self.X_data)


train_dataset = ClassifierDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train).long())
val_dataset = ClassifierDataset(torch.from_numpy(X_val).float(), torch.from_numpy(y_val).long())
test_dataset = ClassifierDataset(torch.from_numpy(X_test).float(), torch.from_numpy(y_test).long())

# %%
target_list = []
for _, t in train_dataset:
    target_list.append(t)

target_list = torch.tensor(target_list)

# %%
class_count = [i for i in get_class_distribution(y_train).values()]
class_weights = 1./torch.tensor(class_count, dtype=torch.float)
print(class_weights)
# Out:
# tensor([0.0047, 0.0455, 0.0769, 0.0714, 0.0714, 0.0526, 0.0556, 0.0714, 0.1250,
#         0.1667, 0.2000,    inf, 0.0909])

# %%
class_weights_all = class_weights[target_list]

# %%
weighted_sampler = WeightedRandomSampler(
    weights=class_weights_all,
    num_samples=len(class_weights_all),
    replacement=True
)

# %%
EPOCHS = 300
BATCH_SIZE = 16
LEARNING_RATE = 0.0007
NUM_FEATURES = len(X.columns)
NUM_CLASSES = 13

# %%
train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE,
                          sampler=weighted_sampler
)
val_loader = DataLoader(dataset=val_dataset, batch_size=1)
test_loader = DataLoader(dataset=test_dataset, batch_size=1)

# %%
class MulticlassClassification(nn.Module):
    def __init__(self, num_feature, num_class):
        super(MulticlassClassification, self).__init__()

        self.layer_1 = nn.Linear(num_feature, 512)
        self.layer_2 = nn.Linear(512, 128)
        self.layer_3 = nn.Linear(128, 64)
        self.layer_out = nn.Linear(64, num_class)

        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.2)
        self.batchnorm1 = nn.BatchNorm1d(512)
        self.batchnorm2 = nn.BatchNorm1d(128)
        self.batchnorm3 = nn.BatchNorm1d(64)

    def forward(self, x):
        x = self.layer_1(x)
        x = self.batchnorm1(x)
        x = self.relu(x)

        x = self.layer_2(x)
        x = self.batchnorm2(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.layer_3(x)
        x = self.batchnorm3(x)
        x = self.relu(x)
        x = self.dropout(x)

        x = self.layer_out(x)

        return x

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
model = MulticlassClassification(num_feature = NUM_FEATURES, num_class=NUM_CLASSES)
model.to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
optimizer = optim.Adam(model.parameters(), lr=0.001)
print(model)
# Out:
# MulticlassClassification(
#   (layer_1): Linear(in_features=18523, out_features=512, bias=True)
#   (layer_2): Linear(in_features=512, out_features=128, bias=True)
#   (layer_3): Linear(in_features=128, out_features=64, bias=True)
#   (layer_out): Linear(in_features=64, out_features=13, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (batchnorm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)

    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)

    acc = torch.round(acc * 100)

    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
print("Begin training.")

for e in tqdm(range(1, EPOCHS+1)):

    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0

    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()

        y_train_pred = model(X_train_batch)

        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)

        train_loss.backward()
        optimizer.step()

        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()


    # VALIDATION
    with torch.no_grad():

        val_epoch_loss = 0
        val_epoch_acc = 0

        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)

            y_val_pred = model(X_val_batch)

            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)

            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()



    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))


    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch 001: | Train Loss: 2.10366 | Val Loss: 2.68985 | Train Acc: 24.478| Val Acc: 0.000
# Epoch 002: | Train Loss: 1.56521 | Val Loss: 2.81200 | Train Acc: 42.783| Val Acc: 0.000
# Epoch 003: | Train Loss: 1.29856 | Val Loss: 2.94455 | Train Acc: 51.522| Val Acc: 2.500
# Epoch 004: | Train Loss: 1.11102 | Val Loss: 3.03232 | Train Acc: 60.826| Val Acc: 7.500
# Epoch 005: | Train Loss: 0.81606 | Val Loss: 3.05257 | Train Acc: 70.565| Val Acc: 0.000
# Epoch 006: | Train Loss: 0.69333 | Val Loss: 3.07418 | Train Acc: 78.174| Val Acc: 5.000
# Epoch 007: | Train Loss: 0.53620 | Val Loss: 3.20127 | Train Acc: 78.261| Val Acc: 7.500
# Epoch 008: | Train Loss: 0.42874 | Val Loss: 3.15648 | Train Acc: 81.652| Val Acc: 2.500
# Epoch 009: | Train Loss: 0.34803 | Val Loss: 3.06643 | Train Acc: 84.913| Val Acc: 5.000
# Epoch 010: | Train Loss: 0.28179 | Val Loss: 3.07096 | Train Acc: 88.957| Val Acc: 5.000
# Epoch 011: | Train Loss: 0.24185 | Val Loss: 3.11203 | Train Acc: 90.609| Val Acc: 5.000
# Epoch 012: | Train Loss: 0.18796 | Val Loss: 3.21516 | Train Acc: 94.174| Val Acc: 10.000
# Epoch 013: | Train Loss: 0.16451 | Val Loss: 3.20317 | Train Acc: 93.826| Val Acc: 2.500
# Epoch 014: | Train Loss: 0.13165 | Val Loss: 3.29389 | Train Acc: 90.957| Val Acc: 7.500
# Epoch 015: | Train Loss: 0.11187 | Val Loss: 3.27507 | Train Acc: 91.391| Val Acc: 7.500
# Epoch 016: | Train Loss: 0.09163 | Val Loss: 3.11603 | Train Acc: 93.174| Val Acc: 10.000
# Epoch 017: | Train Loss: 0.10290 | Val Loss: 3.19522 | Train Acc: 90.478| Val Acc: 10.000
# Epoch 018: | Train Loss: 0.08289 | Val Loss: 3.09984 | Train Acc: 94.174| Val Acc: 12.500
# Epoch 019: | Train Loss: 0.07142 | Val Loss: 3.17432 | Train Acc: 91.913| Val Acc: 10.000
# Epoch 020: | Train Loss: 0.07881 | Val Loss: 3.11970 | Train Acc: 92.609| Val Acc: 7.500
# Epoch 021: | Train Loss: 0.08437 | Val Loss: 3.28752 | Train Acc: 93.870| Val Acc: 2.500
# Epoch 022: | Train Loss: 0.07076 | Val Loss: 3.25505 | Train Acc: 95.043| Val Acc: 2.500
# Epoch 023: | Train Loss: 0.06768 | Val Loss: 3.22434 | Train Acc: 95.217| Val Acc: 5.000
# Epoch 024: | Train Loss: 0.05201 | Val Loss: 3.09025 | Train Acc: 94.217| Val Acc: 10.000
# Epoch 025: | Train Loss: 0.07119 | Val Loss: 3.18240 | Train Acc: 92.783| Val Acc: 7.500
# Epoch 026: | Train Loss: 0.05589 | Val Loss: 2.97235 | Train Acc: 90.391| Val Acc: 5.000
# Epoch 027: | Train Loss: 0.06408 | Val Loss: 2.83752 | Train Acc: 91.435| Val Acc: 10.000
# Epoch 028: | Train Loss: 0.04240 | Val Loss: 2.76184 | Train Acc: 94.000| Val Acc: 15.000
# Epoch 029: | Train Loss: 0.04997 | Val Loss: 2.84987 | Train Acc: 89.261| Val Acc: 12.500
# Epoch 030: | Train Loss: 0.11357 | Val Loss: 2.78548 | Train Acc: 91.478| Val Acc: 10.000
# Epoch 031: | Train Loss: 0.10380 | Val Loss: 3.14541 | Train Acc: 88.696| Val Acc: 7.500
# Epoch 032: | Train Loss: 0.11322 | Val Loss: 3.00436 | Train Acc: 88.087| Val Acc: 5.000
# Epoch 033: | Train Loss: 0.06527 | Val Loss: 3.06167 | Train Acc: 90.000| Val Acc: 2.500
# Epoch 034: | Train Loss: 0.08558 | Val Loss: 2.82072 | Train Acc: 91.522| Val Acc: 5.000
# Epoch 035: | Train Loss: 0.05608 | Val Loss: 2.81339 | Train Acc: 89.478| Val Acc: 10.000
# Epoch 036: | Train Loss: 0.09269 | Val Loss: 2.76164 | Train Acc: 89.565| Val Acc: 10.000
# Epoch 037: | Train Loss: 0.05755 | Val Loss: 2.87238 | Train Acc: 90.087| Val Acc: 10.000
# Epoch 038: | Train Loss: 0.05429 | Val Loss: 2.82975 | Train Acc: 93.739| Val Acc: 7.500
# Epoch 039: | Train Loss: 0.04083 | Val Loss: 2.71064 | Train Acc: 93.174| Val Acc: 5.000
# Epoch 040: | Train Loss: 0.04317 | Val Loss: 2.81637 | Train Acc: 93.391| Val Acc: 12.500
# Epoch 041: | Train Loss: 0.03604 | Val Loss: 2.76723 | Train Acc: 91.478| Val Acc: 15.000
# Epoch 042: | Train Loss: 0.03125 | Val Loss: 2.75259 | Train Acc: 92.565| Val Acc: 15.000
# Epoch 043: | Train Loss: 0.02756 | Val Loss: 2.70729 | Train Acc: 91.391| Val Acc: 20.000
# Epoch 044: | Train Loss: 0.02740 | Val Loss: 2.52704 | Train Acc: 92.783| Val Acc: 20.000
# Epoch 045: | Train Loss: 0.02649 | Val Loss: 2.61025 | Train Acc: 94.609| Val Acc: 27.500
# Epoch 046: | Train Loss: 0.02982 | Val Loss: 2.58714 | Train Acc: 92.478| Val Acc: 20.000
# Epoch 047: | Train Loss: 0.02599 | Val Loss: 2.49085 | Train Acc: 93.435| Val Acc: 27.500
# Epoch 048: | Train Loss: 0.03690 | Val Loss: 2.48731 | Train Acc: 94.043| Val Acc: 27.500
# Epoch 049: | Train Loss: 0.03966 | Val Loss: 2.54078 | Train Acc: 95.304| Val Acc: 17.500
# Epoch 050: | Train Loss: 0.03211 | Val Loss: 2.56640 | Train Acc: 93.652| Val Acc: 22.500
# Epoch 051: | Train Loss: 0.05663 | Val Loss: 2.66795 | Train Acc: 91.826| Val Acc: 10.000
# Epoch 052: | Train Loss: 0.05822 | Val Loss: 2.35992 | Train Acc: 95.000| Val Acc: 15.000
# Epoch 053: | Train Loss: 0.06406 | Val Loss: 2.46514 | Train Acc: 90.609| Val Acc: 20.000
# Epoch 054: | Train Loss: 0.03537 | Val Loss: 2.45236 | Train Acc: 91.217| Val Acc: 25.000
# Epoch 055: | Train Loss: 0.03508 | Val Loss: 2.35581 | Train Acc: 94.217| Val Acc: 15.000
# Epoch 056: | Train Loss: 0.03798 | Val Loss: 2.42600 | Train Acc: 92.565| Val Acc: 17.500
# Epoch 057: | Train Loss: 0.03204 | Val Loss: 2.12712 | Train Acc: 95.130| Val Acc: 25.000
# Epoch 058: | Train Loss: 0.04109 | Val Loss: 2.26884 | Train Acc: 91.174| Val Acc: 27.500
# Epoch 059: | Train Loss: 0.03930 | Val Loss: 2.31306 | Train Acc: 91.826| Val Acc: 25.000
# Epoch 060: | Train Loss: 0.02932 | Val Loss: 2.21713 | Train Acc: 93.304| Val Acc: 27.500
# Epoch 061: | Train Loss: 0.02433 | Val Loss: 2.16998 | Train Acc: 97.130| Val Acc: 30.000
# Epoch 062: | Train Loss: 0.03176 | Val Loss: 2.21123 | Train Acc: 94.087| Val Acc: 27.500
# Epoch 063: | Train Loss: 0.03056 | Val Loss: 2.58640 | Train Acc: 94.783| Val Acc: 30.000
# Epoch 064: | Train Loss: 0.02401 | Val Loss: 2.56204 | Train Acc: 97.130| Val Acc: 27.500
# Epoch 065: | Train Loss: 0.01707 | Val Loss: 2.34748 | Train Acc: 96.870| Val Acc: 32.500
# Epoch 066: | Train Loss: 0.02974 | Val Loss: 2.12182 | Train Acc: 95.739| Val Acc: 37.500
# Epoch 067: | Train Loss: 0.04861 | Val Loss: 2.42082 | Train Acc: 93.913| Val Acc: 30.000
# Epoch 068: | Train Loss: 0.05638 | Val Loss: 2.15908 | Train Acc: 94.652| Val Acc: 35.000
# Epoch 069: | Train Loss: 0.03324 | Val Loss: 2.47611 | Train Acc: 95.783| Val Acc: 27.500
# Epoch 070: | Train Loss: 0.02477 | Val Loss: 2.50055 | Train Acc: 93.217| Val Acc: 27.500
# Epoch 071: | Train Loss: 0.01896 | Val Loss: 2.16890 | Train Acc: 96.348| Val Acc: 37.500
# Epoch 072: | Train Loss: 0.01779 | Val Loss: 2.19297 | Train Acc: 96.304| Val Acc: 42.500
# Epoch 073: | Train Loss: 0.10145 | Val Loss: 2.26823 | Train Acc: 92.870| Val Acc: 42.500
# Epoch 074: | Train Loss: 0.07002 | Val Loss: 2.84129 | Train Acc: 92.130| Val Acc: 17.500
# Epoch 075: | Train Loss: 0.04856 | Val Loss: 2.48208 | Train Acc: 94.348| Val Acc: 32.500
# Epoch 076: | Train Loss: 0.06313 | Val Loss: 2.77809 | Train Acc: 93.174| Val Acc: 22.500
# Epoch 077: | Train Loss: 0.06019 | Val Loss: 2.59432 | Train Acc: 95.957| Val Acc: 30.000
# Epoch 078: | Train Loss: 0.07441 | Val Loss: 3.13504 | Train Acc: 94.565| Val Acc: 22.500
# Epoch 079: | Train Loss: 0.07687 | Val Loss: 2.98918 | Train Acc: 91.217| Val Acc: 20.000
# Epoch 080: | Train Loss: 0.03964 | Val Loss: 3.24505 | Train Acc: 94.478| Val Acc: 17.500
# Epoch 081: | Train Loss: 0.04011 | Val Loss: 2.81478 | Train Acc: 95.000| Val Acc: 20.000
# Epoch 082: | Train Loss: 0.02675 | Val Loss: 2.51361 | Train Acc: 94.130| Val Acc: 30.000
# Epoch 083: | Train Loss: 0.02483 | Val Loss: 2.52726 | Train Acc: 93.652| Val Acc: 27.500
# Epoch 084: | Train Loss: 0.02859 | Val Loss: 2.28011 | Train Acc: 96.261| Val Acc: 35.000
# Epoch 085: | Train Loss: 0.01803 | Val Loss: 2.31751 | Train Acc: 95.783| Val Acc: 40.000
# Epoch 086: | Train Loss: 0.02311 | Val Loss: 2.21186 | Train Acc: 96.609| Val Acc: 42.500
# Epoch 087: | Train Loss: 0.01732 | Val Loss: 2.30878 | Train Acc: 96.826| Val Acc: 37.500
# Epoch 088: | Train Loss: 0.01619 | Val Loss: 2.24596 | Train Acc: 97.913| Val Acc: 45.000
# Epoch 089: | Train Loss: 0.01396 | Val Loss: 2.17081 | Train Acc: 97.130| Val Acc: 47.500
# Epoch 090: | Train Loss: 0.01584 | Val Loss: 2.18766 | Train Acc: 96.609| Val Acc: 45.000
# Epoch 091: | Train Loss: 0.01395 | Val Loss: 2.20579 | Train Acc: 97.130| Val Acc: 45.000
# Epoch 092: | Train Loss: 0.01399 | Val Loss: 2.14335 | Train Acc: 96.522| Val Acc: 50.000
# Epoch 093: | Train Loss: 0.01248 | Val Loss: 2.21786 | Train Acc: 97.826| Val Acc: 50.000
# Epoch 094: | Train Loss: 0.01315 | Val Loss: 2.51791 | Train Acc: 96.087| Val Acc: 45.000
# Epoch 095: | Train Loss: 0.00920 | Val Loss: 2.47485 | Train Acc: 97.652| Val Acc: 45.000
# Epoch 096: | Train Loss: 0.03897 | Val Loss: 2.78074 | Train Acc: 96.478| Val Acc: 40.000
# Epoch 097: | Train Loss: 0.02593 | Val Loss: 2.84478 | Train Acc: 96.565| Val Acc: 27.500
# Epoch 098: | Train Loss: 0.01707 | Val Loss: 2.59072 | Train Acc: 98.435| Val Acc: 35.000
# Epoch 099: | Train Loss: 0.02692 | Val Loss: 2.57571 | Train Acc: 96.522| Val Acc: 32.500
# Epoch 100: | Train Loss: 0.02011 | Val Loss: 2.66142 | Train Acc: 96.783| Val Acc: 32.500
# Epoch 101: | Train Loss: 0.01619 | Val Loss: 2.67154 | Train Acc: 96.174| Val Acc: 30.000
# Epoch 102: | Train Loss: 0.02285 | Val Loss: 2.37915 | Train Acc: 96.870| Val Acc: 37.500
# Epoch 103: | Train Loss: 0.01859 | Val Loss: 2.34078 | Train Acc: 94.870| Val Acc: 37.500
# Epoch 104: | Train Loss: 0.01419 | Val Loss: 2.31702 | Train Acc: 97.304| Val Acc: 40.000
# Epoch 105: | Train Loss: 0.01883 | Val Loss: 2.39329 | Train Acc: 98.435| Val Acc: 47.500
# Epoch 106: | Train Loss: 0.00988 | Val Loss: 2.49948 | Train Acc: 97.043| Val Acc: 37.500
# Epoch 107: | Train Loss: 0.01071 | Val Loss: 2.43985 | Train Acc: 97.913| Val Acc: 42.500
# Epoch 108: | Train Loss: 0.01488 | Val Loss: 2.35456 | Train Acc: 97.565| Val Acc: 50.000
# Epoch 109: | Train Loss: 0.01275 | Val Loss: 2.35301 | Train Acc: 97.652| Val Acc: 47.500
# Epoch 110: | Train Loss: 0.02215 | Val Loss: 2.45067 | Train Acc: 97.652| Val Acc: 42.500
# Epoch 111: | Train Loss: 0.00893 | Val Loss: 2.37140 | Train Acc: 97.826| Val Acc: 42.500
# Epoch 112: | Train Loss: 0.00771 | Val Loss: 2.35538 | Train Acc: 98.130| Val Acc: 47.500
# Epoch 113: | Train Loss: 0.01578 | Val Loss: 2.33350 | Train Acc: 97.130| Val Acc: 47.500
# Epoch 114: | Train Loss: 0.01575 | Val Loss: 2.31925 | Train Acc: 97.913| Val Acc: 50.000
# Epoch 115: | Train Loss: 0.01530 | Val Loss: 2.30426 | Train Acc: 97.304| Val Acc: 50.000
# Epoch 116: | Train Loss: 0.00607 | Val Loss: 2.42411 | Train Acc: 98.609| Val Acc: 52.500
# Epoch 117: | Train Loss: 0.00777 | Val Loss: 2.39749 | Train Acc: 97.913| Val Acc: 42.500
# Epoch 118: | Train Loss: 0.00556 | Val Loss: 2.53430 | Train Acc: 98.870| Val Acc: 45.000
# Epoch 119: | Train Loss: 0.00664 | Val Loss: 2.33724 | Train Acc: 98.957| Val Acc: 47.500
# Epoch 120: | Train Loss: 0.01881 | Val Loss: 2.60527 | Train Acc: 98.435| Val Acc: 40.000
# Epoch 121: | Train Loss: 0.03071 | Val Loss: 2.44662 | Train Acc: 97.565| Val Acc: 40.000
# Epoch 122: | Train Loss: 0.02719 | Val Loss: 2.34340 | Train Acc: 96.609| Val Acc: 45.000
# Epoch 123: | Train Loss: 0.01472 | Val Loss: 2.61950 | Train Acc: 97.913| Val Acc: 50.000
# Epoch 124: | Train Loss: 0.01713 | Val Loss: 2.65836 | Train Acc: 98.130| Val Acc: 52.500
# Epoch 125: | Train Loss: 0.07657 | Val Loss: 2.79121 | Train Acc: 95.609| Val Acc: 37.500
# Epoch 126: | Train Loss: 0.12402 | Val Loss: 2.61685 | Train Acc: 93.870| Val Acc: 35.000
# Epoch 127: | Train Loss: 0.03222 | Val Loss: 2.32823 | Train Acc: 96.609| Val Acc: 42.500
# Epoch 128: | Train Loss: 0.02212 | Val Loss: 2.33448 | Train Acc: 96.652| Val Acc: 42.500
# Epoch 129: | Train Loss: 0.02600 | Val Loss: 2.47850 | Train Acc: 94.870| Val Acc: 40.000
# Epoch 130: | Train Loss: 0.00919 | Val Loss: 2.50902 | Train Acc: 98.348| Val Acc: 40.000
# Epoch 131: | Train Loss: 0.00891 | Val Loss: 2.43822 | Train Acc: 99.130| Val Acc: 45.000
# Epoch 132: | Train Loss: 0.01038 | Val Loss: 2.43026 | Train Acc: 96.783| Val Acc: 45.000
# Epoch 133: | Train Loss: 0.00947 | Val Loss: 2.56653 | Train Acc: 99.739| Val Acc: 50.000
# Epoch 134: | Train Loss: 0.00383 | Val Loss: 2.48340 | Train Acc: 98.957| Val Acc: 47.500
# Epoch 135: | Train Loss: 0.00524 | Val Loss: 2.48601 | Train Acc: 99.217| Val Acc: 47.500
# Epoch 136: | Train Loss: 0.00551 | Val Loss: 2.62789 | Train Acc: 98.435| Val Acc: 47.500
# Epoch 137: | Train Loss: 0.02487 | Val Loss: 2.50641 | Train Acc: 97.391| Val Acc: 50.000
# Epoch 138: | Train Loss: 0.03815 | Val Loss: 2.67434 | Train Acc: 97.652| Val Acc: 45.000
# Epoch 139: | Train Loss: 0.02264 | Val Loss: 2.64461 | Train Acc: 97.565| Val Acc: 45.000
# Epoch 140: | Train Loss: 0.03038 | Val Loss: 3.25003 | Train Acc: 97.130| Val Acc: 32.500
# Epoch 141: | Train Loss: 0.03328 | Val Loss: 3.10523 | Train Acc: 96.826| Val Acc: 37.500
# Epoch 142: | Train Loss: 0.02094 | Val Loss: 3.04513 | Train Acc: 96.565| Val Acc: 40.000
# Epoch 143: | Train Loss: 0.01144 | Val Loss: 2.89999 | Train Acc: 97.826| Val Acc: 47.500
# Epoch 144: | Train Loss: 0.06430 | Val Loss: 2.97056 | Train Acc: 95.783| Val Acc: 42.500
# Epoch 145: | Train Loss: 0.08324 | Val Loss: 2.91151 | Train Acc: 97.130| Val Acc: 50.000
# Epoch 146: | Train Loss: 0.06596 | Val Loss: 2.58159 | Train Acc: 95.696| Val Acc: 52.500
# Epoch 147: | Train Loss: 0.05225 | Val Loss: 2.66899 | Train Acc: 96.348| Val Acc: 47.500
# Epoch 148: | Train Loss: 0.04817 | Val Loss: 2.67342 | Train Acc: 94.652| Val Acc: 42.500
# Epoch 149: | Train Loss: 0.04957 | Val Loss: 2.98111 | Train Acc: 94.652| Val Acc: 32.500
# Epoch 150: | Train Loss: 0.02943 | Val Loss: 2.62281 | Train Acc: 96.870| Val Acc: 42.500
# Epoch 151: | Train Loss: 0.02149 | Val Loss: 2.61543 | Train Acc: 96.609| Val Acc: 32.500
# Epoch 152: | Train Loss: 0.01332 | Val Loss: 2.60041 | Train Acc: 97.130| Val Acc: 42.500
# Epoch 153: | Train Loss: 0.01760 | Val Loss: 2.70750 | Train Acc: 97.130| Val Acc: 45.000
# Epoch 154: | Train Loss: 0.02407 | Val Loss: 2.67102 | Train Acc: 96.565| Val Acc: 45.000
# Epoch 155: | Train Loss: 0.01543 | Val Loss: 2.65020 | Train Acc: 98.174| Val Acc: 45.000
# Epoch 156: | Train Loss: 0.01540 | Val Loss: 2.71559 | Train Acc: 97.348| Val Acc: 45.000
# Epoch 157: | Train Loss: 0.00813 | Val Loss: 2.69248 | Train Acc: 98.087| Val Acc: 45.000
# Epoch 158: | Train Loss: 0.00852 | Val Loss: 2.67580 | Train Acc: 97.826| Val Acc: 42.500
# Epoch 159: | Train Loss: 0.00560 | Val Loss: 2.68871 | Train Acc: 98.696| Val Acc: 50.000
# Epoch 160: | Train Loss: 0.00853 | Val Loss: 2.75675 | Train Acc: 98.174| Val Acc: 47.500
# Epoch 161: | Train Loss: 0.01072 | Val Loss: 2.76633 | Train Acc: 97.522| Val Acc: 45.000
# Epoch 162: | Train Loss: 0.01432 | Val Loss: 2.82531 | Train Acc: 98.348| Val Acc: 42.500
# Epoch 163: | Train Loss: 0.01738 | Val Loss: 2.60074 | Train Acc: 98.087| Val Acc: 47.500
# Epoch 164: | Train Loss: 0.00759 | Val Loss: 2.45723 | Train Acc: 99.478| Val Acc: 52.500
# Epoch 165: | Train Loss: 0.01445 | Val Loss: 2.55635 | Train Acc: 98.174| Val Acc: 45.000
# Epoch 166: | Train Loss: 0.01399 | Val Loss: 2.68517 | Train Acc: 97.565| Val Acc: 45.000
# Epoch 167: | Train Loss: 0.02050 | Val Loss: 2.48652 | Train Acc: 97.348| Val Acc: 47.500
# Epoch 168: | Train Loss: 0.00804 | Val Loss: 2.62801 | Train Acc: 97.913| Val Acc: 42.500
# Epoch 169: | Train Loss: 0.01110 | Val Loss: 2.57488 | Train Acc: 98.174| Val Acc: 45.000
# Epoch 170: | Train Loss: 0.00960 | Val Loss: 2.54997 | Train Acc: 98.174| Val Acc: 50.000
# Epoch 171: | Train Loss: 0.00375 | Val Loss: 2.65762 | Train Acc: 99.217| Val Acc: 42.500
# Epoch 172: | Train Loss: 0.00758 | Val Loss: 2.63514 | Train Acc: 98.174| Val Acc: 47.500
# Epoch 173: | Train Loss: 0.00439 | Val Loss: 2.85324 | Train Acc: 99.478| Val Acc: 45.000
# Epoch 174: | Train Loss: 0.00598 | Val Loss: 2.93954 | Train Acc: 98.435| Val Acc: 42.500
# Epoch 175: | Train Loss: 0.00456 | Val Loss: 2.68604 | Train Acc: 98.696| Val Acc: 50.000
# Epoch 176: | Train Loss: 0.00648 | Val Loss: 2.96881 | Train Acc: 98.957| Val Acc: 50.000
# Epoch 177: | Train Loss: 0.00577 | Val Loss: 2.89533 | Train Acc: 98.957| Val Acc: 50.000
# Epoch 178: | Train Loss: 0.00282 | Val Loss: 2.87941 | Train Acc: 100.000| Val Acc: 47.500
# Epoch 179: | Train Loss: 0.00619 | Val Loss: 3.02478 | Train Acc: 98.957| Val Acc: 50.000
# Epoch 180: | Train Loss: 0.00911 | Val Loss: 2.76543 | Train Acc: 98.696| Val Acc: 42.500
# Epoch 181: | Train Loss: 0.00614 | Val Loss: 2.76712 | Train Acc: 98.957| Val Acc: 52.500
# Epoch 182: | Train Loss: 0.00534 | Val Loss: 2.75802 | Train Acc: 99.478| Val Acc: 50.000
# Epoch 183: | Train Loss: 0.00370 | Val Loss: 2.67433 | Train Acc: 98.957| Val Acc: 55.000
# Epoch 184: | Train Loss: 0.05866 | Val Loss: 2.68048 | Train Acc: 98.870| Val Acc: 55.000
# Epoch 185: | Train Loss: 0.02990 | Val Loss: 2.79320 | Train Acc: 97.957| Val Acc: 52.500
# Epoch 186: | Train Loss: 0.03614 | Val Loss: 3.06572 | Train Acc: 97.304| Val Acc: 50.000
# Epoch 187: | Train Loss: 0.02171 | Val Loss: 2.96457 | Train Acc: 97.304| Val Acc: 45.000
# Epoch 188: | Train Loss: 0.01402 | Val Loss: 3.16625 | Train Acc: 98.087| Val Acc: 47.500
# Epoch 189: | Train Loss: 0.00494 | Val Loss: 3.21785 | Train Acc: 98.957| Val Acc: 52.500
# Epoch 190: | Train Loss: 0.00354 | Val Loss: 3.06524 | Train Acc: 99.478| Val Acc: 52.500
# Epoch 191: | Train Loss: 0.00752 | Val Loss: 3.00888 | Train Acc: 99.478| Val Acc: 50.000
# Epoch 192: | Train Loss: 0.00517 | Val Loss: 2.97859 | Train Acc: 99.739| Val Acc: 52.500
# Epoch 193: | Train Loss: 0.00729 | Val Loss: 2.93947 | Train Acc: 98.957| Val Acc: 55.000
# Epoch 194: | Train Loss: 0.01685 | Val Loss: 3.11962 | Train Acc: 99.174| Val Acc: 50.000
# Epoch 195: | Train Loss: 0.00574 | Val Loss: 3.37587 | Train Acc: 98.957| Val Acc: 45.000
# Epoch 196: | Train Loss: 0.00999 | Val Loss: 3.17448 | Train Acc: 98.957| Val Acc: 45.000
# Epoch 197: | Train Loss: 0.01099 | Val Loss: 3.04514 | Train Acc: 98.957| Val Acc: 47.500
# Epoch 198: | Train Loss: 0.02303 | Val Loss: 3.33902 | Train Acc: 97.609| Val Acc: 42.500
# Epoch 199: | Train Loss: 0.00846 | Val Loss: 3.10456 | Train Acc: 98.435| Val Acc: 45.000
# Epoch 200: | Train Loss: 0.01002 | Val Loss: 3.43587 | Train Acc: 97.565| Val Acc: 42.500
# Epoch 201: | Train Loss: 0.01949 | Val Loss: 3.79044 | Train Acc: 97.435| Val Acc: 42.500
# Epoch 202: | Train Loss: 0.07755 | Val Loss: 3.46565 | Train Acc: 97.826| Val Acc: 42.500
# Epoch 203: | Train Loss: 0.04523 | Val Loss: 3.21290 | Train Acc: 97.348| Val Acc: 47.500
# Epoch 204: | Train Loss: 0.01316 | Val Loss: 2.97405 | Train Acc: 98.957| Val Acc: 47.500
# Epoch 205: | Train Loss: 0.02095 | Val Loss: 2.82054 | Train Acc: 96.652| Val Acc: 45.000
# Epoch 206: | Train Loss: 0.01337 | Val Loss: 2.71430 | Train Acc: 97.304| Val Acc: 52.500
# Epoch 207: | Train Loss: 0.00780 | Val Loss: 2.86954 | Train Acc: 98.435| Val Acc: 50.000
# Epoch 208: | Train Loss: 0.01352 | Val Loss: 2.98015 | Train Acc: 98.609| Val Acc: 52.500
# Epoch 209: | Train Loss: 0.00984 | Val Loss: 3.11446 | Train Acc: 98.696| Val Acc: 47.500
# Epoch 210: | Train Loss: 0.01503 | Val Loss: 2.80194 | Train Acc: 97.043| Val Acc: 40.000
# Epoch 211: | Train Loss: 0.02279 | Val Loss: 2.88824 | Train Acc: 98.348| Val Acc: 50.000
# Epoch 212: | Train Loss: 0.00572 | Val Loss: 2.93626 | Train Acc: 99.478| Val Acc: 45.000
# Epoch 213: | Train Loss: 0.03350 | Val Loss: 2.84003 | Train Acc: 97.565| Val Acc: 42.500
# Epoch 214: | Train Loss: 0.00754 | Val Loss: 3.08475 | Train Acc: 98.696| Val Acc: 47.500
# Epoch 215: | Train Loss: 0.01140 | Val Loss: 3.13288 | Train Acc: 98.435| Val Acc: 47.500
# Epoch 216: | Train Loss: 0.01644 | Val Loss: 3.04449 | Train Acc: 97.130| Val Acc: 42.500
# Epoch 217: | Train Loss: 0.00381 | Val Loss: 3.03225 | Train Acc: 99.739| Val Acc: 47.500
# Epoch 218: | Train Loss: 0.00670 | Val Loss: 3.22425 | Train Acc: 99.739| Val Acc: 50.000
# Epoch 219: | Train Loss: 0.00898 | Val Loss: 3.29742 | Train Acc: 98.870| Val Acc: 50.000
# Epoch 220: | Train Loss: 0.01064 | Val Loss: 3.25559 | Train Acc: 98.957| Val Acc: 50.000
# Epoch 221: | Train Loss: 0.02087 | Val Loss: 3.14646 | Train Acc: 97.261| Val Acc: 52.500
# Epoch 222: | Train Loss: 0.01021 | Val Loss: 3.18123 | Train Acc: 99.739| Val Acc: 50.000
# Epoch 223: | Train Loss: 0.00804 | Val Loss: 3.37123 | Train Acc: 98.696| Val Acc: 40.000
# Epoch 224: | Train Loss: 0.01085 | Val Loss: 3.11511 | Train Acc: 98.174| Val Acc: 42.500
# Epoch 225: | Train Loss: 0.01359 | Val Loss: 3.38353 | Train Acc: 98.087| Val Acc: 47.500
# Epoch 226: | Train Loss: 0.00820 | Val Loss: 2.99018 | Train Acc: 98.957| Val Acc: 47.500
# Epoch 227: | Train Loss: 0.00470 | Val Loss: 3.10380 | Train Acc: 98.957| Val Acc: 47.500
# Epoch 228: | Train Loss: 0.00194 | Val Loss: 3.14860 | Train Acc: 99.739| Val Acc: 47.500
# Epoch 229: | Train Loss: 0.00912 | Val Loss: 3.21068 | Train Acc: 98.348| Val Acc: 47.500
# Epoch 230: | Train Loss: 0.00854 | Val Loss: 3.09903 | Train Acc: 99.130| Val Acc: 55.000
# Epoch 231: | Train Loss: 0.00389 | Val Loss: 2.97746 | Train Acc: 100.000| Val Acc: 47.500
# Epoch 232: | Train Loss: 0.00716 | Val Loss: 2.97939 | Train Acc: 99.217| Val Acc: 55.000
# Epoch 233: | Train Loss: 0.02170 | Val Loss: 3.11764 | Train Acc: 97.391| Val Acc: 52.500
# Epoch 234: | Train Loss: 0.01049 | Val Loss: 3.08402 | Train Acc: 98.870| Val Acc: 50.000
# Epoch 235: | Train Loss: 0.03393 | Val Loss: 3.16177 | Train Acc: 98.087| Val Acc: 55.000
# Epoch 236: | Train Loss: 0.01768 | Val Loss: 3.06838 | Train Acc: 98.174| Val Acc: 50.000
# Epoch 237: | Train Loss: 0.02021 | Val Loss: 3.16217 | Train Acc: 97.391| Val Acc: 37.500
# Epoch 238: | Train Loss: 0.00966 | Val Loss: 2.88415 | Train Acc: 99.217| Val Acc: 47.500
# Epoch 239: | Train Loss: 0.00372 | Val Loss: 2.80847 | Train Acc: 99.217| Val Acc: 47.500
# Epoch 240: | Train Loss: 0.00937 | Val Loss: 2.86565 | Train Acc: 97.826| Val Acc: 47.500
# Epoch 241: | Train Loss: 0.00416 | Val Loss: 2.78792 | Train Acc: 98.696| Val Acc: 52.500
# Epoch 242: | Train Loss: 0.00714 | Val Loss: 2.77964 | Train Acc: 98.174| Val Acc: 52.500
# Epoch 243: | Train Loss: 0.00567 | Val Loss: 2.89160 | Train Acc: 98.696| Val Acc: 52.500
# Epoch 244: | Train Loss: 0.00711 | Val Loss: 3.09596 | Train Acc: 98.435| Val Acc: 52.500
# Epoch 245: | Train Loss: 0.00495 | Val Loss: 2.92678 | Train Acc: 99.217| Val Acc: 55.000
# Epoch 246: | Train Loss: 0.03986 | Val Loss: 3.06596 | Train Acc: 98.739| Val Acc: 55.000
# Epoch 247: | Train Loss: 0.07265 | Val Loss: 3.21000 | Train Acc: 98.435| Val Acc: 50.000
# Epoch 248: | Train Loss: 0.01729 | Val Loss: 3.05086 | Train Acc: 98.696| Val Acc: 47.500
# Epoch 249: | Train Loss: 0.01269 | Val Loss: 3.16421 | Train Acc: 98.130| Val Acc: 47.500
# Epoch 250: | Train Loss: 0.00523 | Val Loss: 3.20849 | Train Acc: 98.957| Val Acc: 52.500
# Epoch 251: | Train Loss: 0.01095 | Val Loss: 2.97522 | Train Acc: 98.435| Val Acc: 47.500
# Epoch 252: | Train Loss: 0.03212 | Val Loss: 3.12709 | Train Acc: 96.000| Val Acc: 30.000
# Epoch 253: | Train Loss: 0.00902 | Val Loss: 2.65909 | Train Acc: 97.826| Val Acc: 45.000
# Epoch 254: | Train Loss: 0.00765 | Val Loss: 2.70787 | Train Acc: 97.652| Val Acc: 50.000
# Epoch 255: | Train Loss: 0.02282 | Val Loss: 2.74173 | Train Acc: 98.174| Val Acc: 45.000
# Epoch 256: | Train Loss: 0.00816 | Val Loss: 2.70541 | Train Acc: 98.174| Val Acc: 52.500
# Epoch 257: | Train Loss: 0.00573 | Val Loss: 2.66868 | Train Acc: 98.696| Val Acc: 50.000
# Epoch 258: | Train Loss: 0.00700 | Val Loss: 2.75250 | Train Acc: 98.696| Val Acc: 50.000
# Epoch 259: | Train Loss: 0.00296 | Val Loss: 2.91260 | Train Acc: 98.957| Val Acc: 45.000
# Epoch 260: | Train Loss: 0.01121 | Val Loss: 2.83904 | Train Acc: 97.913| Val Acc: 47.500
# Epoch 261: | Train Loss: 0.00584 | Val Loss: 2.87492 | Train Acc: 99.217| Val Acc: 50.000
# Epoch 262: | Train Loss: 0.00279 | Val Loss: 2.86033 | Train Acc: 99.217| Val Acc: 47.500
# Epoch 263: | Train Loss: 0.00479 | Val Loss: 2.82752 | Train Acc: 99.217| Val Acc: 57.500
# Epoch 264: | Train Loss: 0.00540 | Val Loss: 2.83490 | Train Acc: 99.739| Val Acc: 57.500
# Epoch 265: | Train Loss: 0.00583 | Val Loss: 2.87333 | Train Acc: 98.957| Val Acc: 47.500
# Epoch 266: | Train Loss: 0.00646 | Val Loss: 3.03839 | Train Acc: 99.217| Val Acc: 52.500
# Epoch 267: | Train Loss: 0.00673 | Val Loss: 2.80759 | Train Acc: 98.957| Val Acc: 55.000
# Epoch 268: | Train Loss: 0.00860 | Val Loss: 2.84022 | Train Acc: 97.870| Val Acc: 55.000
# Epoch 269: | Train Loss: 0.02055 | Val Loss: 2.96409 | Train Acc: 98.957| Val Acc: 50.000
# Epoch 270: | Train Loss: 0.00923 | Val Loss: 2.80851 | Train Acc: 98.957| Val Acc: 52.500
# Epoch 271: | Train Loss: 0.00678 | Val Loss: 2.93245 | Train Acc: 98.435| Val Acc: 52.500
# Epoch 272: | Train Loss: 0.01523 | Val Loss: 2.76506 | Train Acc: 97.609| Val Acc: 52.500
# Epoch 273: | Train Loss: 0.00406 | Val Loss: 2.68181 | Train Acc: 99.217| Val Acc: 52.500
# Epoch 274: | Train Loss: 0.01396 | Val Loss: 2.59501 | Train Acc: 98.957| Val Acc: 57.500
# Epoch 275: | Train Loss: 0.00623 | Val Loss: 2.51748 | Train Acc: 99.217| Val Acc: 52.500
# Epoch 276: | Train Loss: 0.01534 | Val Loss: 2.64345 | Train Acc: 99.739| Val Acc: 55.000
# Epoch 277: | Train Loss: 0.03352 | Val Loss: 2.62479 | Train Acc: 97.000| Val Acc: 52.500
# Epoch 278: | Train Loss: 0.01025 | Val Loss: 2.52820 | Train Acc: 97.913| Val Acc: 52.500
# Epoch 279: | Train Loss: 0.02527 | Val Loss: 2.74299 | Train Acc: 98.609| Val Acc: 52.500
# Epoch 280: | Train Loss: 0.01263 | Val Loss: 2.72116 | Train Acc: 97.652| Val Acc: 55.000
# Epoch 281: | Train Loss: 0.01252 | Val Loss: 2.71536 | Train Acc: 98.609| Val Acc: 52.500
# Epoch 282: | Train Loss: 0.00448 | Val Loss: 2.67981 | Train Acc: 99.478| Val Acc: 52.500
# Epoch 283: | Train Loss: 0.01928 | Val Loss: 2.53017 | Train Acc: 98.174| Val Acc: 55.000
# Epoch 284: | Train Loss: 0.00881 | Val Loss: 2.54681 | Train Acc: 99.739| Val Acc: 55.000
# Epoch 285: | Train Loss: 0.05551 | Val Loss: 2.61088 | Train Acc: 96.261| Val Acc: 52.500
# Epoch 286: | Train Loss: 0.08127 | Val Loss: 2.60442 | Train Acc: 96.130| Val Acc: 40.000
# Epoch 287: | Train Loss: 0.06287 | Val Loss: 2.46081 | Train Acc: 97.043| Val Acc: 47.500
# Epoch 288: | Train Loss: 0.08243 | Val Loss: 2.55023 | Train Acc: 95.609| Val Acc: 52.500
# Epoch 289: | Train Loss: 0.03752 | Val Loss: 2.71492 | Train Acc: 96.565| Val Acc: 50.000
# Epoch 290: | Train Loss: 0.02701 | Val Loss: 2.87048 | Train Acc: 97.043| Val Acc: 50.000
# Epoch 291: | Train Loss: 0.01470 | Val Loss: 2.73249 | Train Acc: 97.826| Val Acc: 55.000
# Epoch 292: | Train Loss: 0.03547 | Val Loss: 2.80557 | Train Acc: 95.304| Val Acc: 50.000
# Epoch 293: | Train Loss: 0.01202 | Val Loss: 2.98722 | Train Acc: 98.696| Val Acc: 50.000
# Epoch 294: | Train Loss: 0.00567 | Val Loss: 2.95171 | Train Acc: 99.739| Val Acc: 57.500
# Epoch 295: | Train Loss: 0.01974 | Val Loss: 3.06509 | Train Acc: 98.174| Val Acc: 52.500
# Epoch 296: | Train Loss: 0.03651 | Val Loss: 2.86836 | Train Acc: 97.565| Val Acc: 52.500
# Epoch 297: | Train Loss: 0.00460 | Val Loss: 2.99905 | Train Acc: 99.739| Val Acc: 50.000
# Epoch 298: | Train Loss: 0.01553 | Val Loss: 3.14319 | Train Acc: 98.696| Val Acc: 52.500
# Epoch 299: | Train Loss: 0.00929 | Val Loss: 3.02972 | Train Acc: 98.696| Val Acc: 50.000
# Epoch 300: | Train Loss: 0.00640 | Val Loss: 2.96366 | Train Acc: 98.957| Val Acc: 52.500

# %%
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(30,10))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
y_pred_list = []

with torch.no_grad():
    model.eval()
    for X_batch, _ in test_loader:
        X_batch = X_batch.to(device)
        y_test_pred = model(X_batch)
        y_pred_softmax = torch.log_softmax(y_test_pred, dim = 1)
        _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)
        y_pred_list.append(y_pred_tags.cpu().numpy())

# %%
y_pred_list = [a.squeeze().tolist() for a in y_pred_list]

# %%
print(y_pred_list)
# Out:
# [0, 0, 0, 0, 12, 0, 0, 0, 0, 6, 0, 0, 0, 0, 0, 0, 0, 3, 0, 0, 0, 0, 12, 0, 5, 0, 0, 0, 0, 0, 0, 0, 0, 12, 0, 0, 5, 3, 0, 0, 0, 0, 0, 0, 0]

# %%
confusion_matrix_df = pd.DataFrame(confusion_matrix(y_test, y_pred_list)).rename(columns=idx2class, index=idx2class)
sns.heatmap(confusion_matrix_df, annot=True)
# Out:
# <AxesSubplot:>

# %%
len(y_pred_list)
# Out:
# 45

# %%
print(classification_report(y_test, y_pred_list))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.89      0.75        27
#          1.0       0.00      0.00      0.00         3
#          2.0       0.00      0.00      0.00         2
#          3.0       0.50      0.50      0.50         2
#          4.0       0.00      0.00      0.00         2
#          5.0       0.50      0.50      0.50         2
#          6.0       0.00      0.00      0.00         2
#          7.0       0.00      0.00      0.00         1
#          8.0       0.00      0.00      0.00         1
#          9.0       0.00      0.00      0.00         1
#         10.0       0.00      0.00      0.00         1
#         12.0       0.00      0.00      0.00         1
#
#     accuracy                           0.58        45
#    macro avg       0.14      0.16      0.15        45
# weighted avg       0.43      0.58      0.49        45
# C:\Users\Udi\Documents\GitHub\RadiationProject\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Udi\Documents\GitHub\RadiationProject\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Udi\Documents\GitHub\RadiationProject\venv\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
